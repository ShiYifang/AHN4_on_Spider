# %%
import pathlib

from laserfarm import Retiler, MacroPipeline

# %% [markdown]
# # Macro-Pipeline AHN Workflow - Retiling

# %% [markdown]
# ## Set input/output paths

# %%
input_path = pathlib.Path("/project/lidarac/Share/users/fnattino/split/")
output_path = pathlib.Path("/project/lidarac/Share/users/fnattino/retiled")

# %%
laz_files = list(input_path.glob("*.LAZ"))
print("Retiling {} LAZ files".format(len(laz_files)))

# %% [markdown]
# ## Setup Cluster
#
# Setup Dask cluster used for the macro-pipeline calculation.

# %%
from dask.distributed import Client

client = Client("tcp://10.0.0.52:33961")
client

# %% [markdown]
# ## Re-tiling
#
# The raw point cloud files are retiled to a regular grid.

# %%
# details of the retiling schema
# bbox for the Netherlands in Amersfoort / RD CRS (EPSG:28992)
grid = {
    "min_x": -113107.81,
    "max_x": 398892.19,
    "min_y": 214783.87,
    "max_y": 726783.87,
    "n_tiles_side": 512
}

# %%
# set path where output will be written
retiling_input = {
    "setup_local_fs": {
        "input_folder": input_path.as_posix(),
        "output_folder": output_path.as_posix(),
    },
    "set_grid": grid,
    "split_and_redistribute": {},
    "validate": {},
}

# %%
macro = MacroPipeline()
# add pipeline list to macro-pipeline object and set the corresponding labels
macro.tasks = [Retiler(file).config(retiling_input) for file in laz_files]
macro.set_labels([file.stem for file in laz_files])

# %%
macro.setup_cluster(cluster=client.scheduler.address)

# %%
# run!
macro.run()

# %%
# save outcome results
macro.print_outcome(to_file="retile.out")

# %%
assert not macro.get_failed_pipelines(), "Some of the tasks have failed!"

# %% [markdown]
# ## Terminate cluster

# %%
# client.close()
# macro.shutdown()
